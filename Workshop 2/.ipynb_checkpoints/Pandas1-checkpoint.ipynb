# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# الطباعة بشكل سيئ
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
#OPTION FOR MAX ROWS
pd.options.display.max_rows
# Out:
# 60

# %%
# OPTION FOR MIN ROWS
pd.options.display.min_rows = 20

# %%
#FIRst ROWs
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
#LASt ROWs
titanic.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %% [markdown]
# # FIRST DATA INSPECTION

# %%
# INFO METHOD 

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#FIND DATA THAT IS DATA TYPE IS OBJECT
titanic.describe(include = "O" )
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ## BUILT IN FUCNTIONS & DATA FRAMES ATTRIBUTES AND METHODS

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic)
# Out:
# 891

# %%
round(titanic , 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# 5           0       3    male   NaN      0      0   8.0        Q  NaN
# 6           0       1    male  54.0      0      0  52.0        S    E
# 7           0       3    male   2.0      3      1  21.0        S  NaN
# 8           1       3  female  27.0      0      2  11.0        S  NaN
# 9           1       2  female  14.0      1      0  30.0        C  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 881         0       3    male  33.0      0      0   8.0        S  NaN
# ...

# %%
int(titanic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18156\3092570746.py in <module>
# ----> 1 int(titanic)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
min(titanic)

# %% [markdown]
# # DATA FRAME ATTRIBUTES

# %%
titanic.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18156\339920278.py in <module>
# ----> 1 titanic.shape
#
# NameError: name 'titanic' is not defined

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# # DATA FRAME METHODS

# %%
titanic.head( n = 2 )

# %%
titanic.min()

# %%
titanic.mean()

# %%
#METHOD CHINING

titanic.mean().sort_values()

# %%
titanic.mean().sort_values().head(2)

# %% [markdown]
# ## SELCETING COLUMNS

# %%
titanic["age"]

# %%
type(titanic['age'])

# %%
titanic[ ["age" , "sex"] ]

# %%
titanic[ ["age" , "sex" , "fare"] ]

# %% [markdown]
# # SELECTING ONECOLUMN WITH DOT NOTATION

# %%
titanic.age.equals(titanic['age'])

# %%
age

# %%
age.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31084\481689255.py in <module>
# ----> 1 age.size
#
# NameError: name 'age' is not defined

# %%
titanic.sizes
# Out:
# 8019

# %%
sum(titaic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31084\103531674.py in <module>
# ----> 1 sum(titaic)
#
# NameError: name 'titaic' is not defined

# %%
titanic.sum()
# Out:
# C:\Users\ammar\AppData\Local\Temp\ipykernel_31084\2139790256.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.sum()
# survived                                                  342
# pclass                                                   2057
# sex         malefemalefemalefemalemalemalemalemalefemalefe...
# age                                                  21205.17
# sibsp                                                     466
# parch                                                     340
# fare                                               28693.9493
# dtype: object

# %%
age.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31084\3258285181.py in <module>
# ----> 1 age.max()
#
# NameError: name 'age' is not defined

# %%
titanic.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31084\1385196575.py in <module>
# ----> 1 titanic.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
titanic.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          88
# sibsp         7
# parch         7
# fare        248
# embarked      3
# deck          7
# dtype: int64

# %%
titanic[titanic.sex == "male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0           0       3  male  22.0      1      0   7.2500        S  NaN
# 4           0       3  male  35.0      0      0   8.0500        S  NaN
# 5           0       3  male   NaN      0      0   8.4583        Q  NaN
# 6           0       1  male  54.0      0      0  51.8625        S    E
# 7           0       3  male   2.0      3      1  21.0750        S  NaN
# 12          0       3  male  20.0      0      0   8.0500        S  NaN
# 13          0       3  male  39.0      1      5  31.2750        S  NaN
# 16          0       3  male   2.0      4      1  29.1250        Q  NaN
# 17          1       2  male   NaN      0      0  13.0000        S  NaN
# 20          0       2  male  35.0      0      0  26.0000        S  NaN
# ..        ...     ...   ...   ...    ...    ...      ...      ...  ...
# 873         0       3  male  47.0      0      0   9.0000        S  NaN
# ...

# %%
titanic[titanic.sex == "female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# 10          1       3  female   4.0      1      1  16.7000        S    G
# 11          1       1  female  58.0      0      0  26.5500        S    C
# 14          0       3  female  14.0      0      0   7.8542        S  NaN
# 15          1       2  female  55.0      0      0  16.0000        S  NaN
# 18          0       3  female  31.0      1      0  18.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 866         1       2  female  27.0      1      0  13.8583        C  NaN
# ...

# %%
titanic[titanic.sex == "male"]["fare"]
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
# 12      8.0500
# 13     31.2750
# 16     29.1250
# 17     13.0000
# 20     26.0000
#         ...
# 873     9.0000
# 876     9.8458
# 877     7.8958
# 878     7.8958
# 881     7.8958
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
mask1 = titanic.sex == "male"
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9      False
#        ...
# 881     True
# 882    False
# 883     True
# 884     True
# 885    False
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
mask2 = titanic.dtypes == object

# %%
mask2
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic.loc[mask1 , ~mask2]
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 4           0       3  35.0      0      0   8.0500
# 5           0       3   NaN      0      0   8.4583
# 6           0       1  54.0      0      0  51.8625
# 7           0       3   2.0      3      1  21.0750
# 12          0       3  20.0      0      0   8.0500
# 13          0       3  39.0      1      5  31.2750
# 16          0       3   2.0      4      1  29.1250
# 17          1       2   NaN      0      0  13.0000
# 20          0       2  35.0      0      0  26.0000
# ..        ...     ...   ...    ...    ...      ...
# 873         0       3  47.0      0      0   9.0000
# 876         0       3  20.0      0      0   9.8458
# 877         0       3  19.0      0      0   7.8958
# 878         0       3   NaN      0      0   7.8958
# 881         0       3  33.0      0      0   7.8958
# 883         0       2  28.0      0      0  10.5000
# ...

# %%
make1 = titanic.sex == "male"
make1.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
mask2 = titanic.age > 14
mask2.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: age, dtype: bool

# %%
( mask1 & mask2 ).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
male_surv = titanic.loc[ mask1 & mask2 , ["survived" , "pclass" , "sex" , "age"] ]
male_surv.head()
# Out:
#     survived  pclass   sex   age
# 0          0       3  male  22.0
# 4          0       3  male  35.0
# 6          0       1  male  54.0
# 12         0       3  male  20.0
# 13         0       3  male  39.0

# %%
male_surv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  414 non-null    int64
#  1   pclass    414 non-null    int64
#  2   sex       414 non-null    object
#  3   age       414 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 16.2+ KB

# %%
male_surv.describe()
# Out:
#          survived      pclass         age
# count  414.000000  414.000000  414.000000
# mean     0.173913    2.309179   33.129227
# std      0.379493    0.829868   12.922177
# min      0.000000    1.000000   15.000000
# 25%      0.000000    2.000000   23.000000
# 50%      0.000000    3.000000   30.000000
# 75%      0.000000    3.000000   40.000000
# max      1.000000    3.000000   80.000000

# %%
(mask1 | mask2 ).head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
titanic.loc[mask1 | mask2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 11          1       1  female  58.0      0      0  26.5500        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# ...

# %%
titanic.loc[mask1 | mask2]
